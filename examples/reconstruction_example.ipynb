# %% [markdown]
# # Reconstruction of estimated glacier states

# %% [markdown]
# We here present a new method to reconstruct past glacier states from climate inforamtion using the Open Glogal Glacier Model. The method consists of three main steps: generation of glacier states, identification of glacier candidates and their evaluation and will be explained in detail in the upcomming paper (submitted). This notebook shows how to apply the developped method. A proper installation of OGGM and all dependencies are required to run this method. Knowledge on how to run OGGM is required!

# %% [markdown]
# ### Set-up

# %%
import sys
import os
import salem

from initialization.core import *
from initialization.plots import *

from oggm import cfg, workflow,utils
#pd.options.mode.chained_assignment = None
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %matplotlib inline
# settings for plots
mpl.rcParams['axes.linewidth'] = 3
mpl.rcParams['xtick.major.width'] = 3
mpl.rcParams['ytick.major.width'] = 3
mpl.rcParams['font.size'] =15
mpl.rcParams['font.weight'] = 'medium'
mpl.rcParams['axes.labelweight'] = 'medium'
mpl.rcParams['legend.fontsize']= 15 
mpl.rcParams['lines.linewidth']=3
mpl.rcParams['figure.figsize'] = 10,10


cfg.initialize()

# path to working and plot directory
WORKING_DIR = '/home/juliaeis/Dokumente/OGGM/work_dir/reconstruction/alps'
cfg.PATHS['working_dir'] = WORKING_DIR
utils.mkdir(cfg.PATHS['working_dir'], reset=False)
cfg.PATHS['plot_dir'] = os.path.join(cfg.PATHS['working_dir'], 'plots')
utils.mkdir(cfg.PATHS['plot_dir'], reset=False)


# Use multiprocessing?
cfg.PARAMS['use_multiprocessing'] = True

# How many grid points around the glacier?
cfg.PARAMS['border'] = 200

# Set to True for operational runs
cfg.PARAMS['continue_on_error'] = True

# We use intersects
db = utils.get_rgi_intersects_region_file(version='61', region='11')
cfg.set_intersects_db(db)

cfg.PARAMS['run_mb_calibration'] = True
cfg.PARAMS['optimize_inversion_params'] = False
# Out:
# /home/juliaeis/.pyvirtualenvs/oggm_env/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# 2019-04-05 13:53:41: oggm.cfg: Using configuration file: /home/juliaeis/oggm-juliaeis/oggm/params.cfg

# %% [markdown]
# ### Glacier outlines and climate data
# The glacier outlines are obtained from the Randolph Glacier Inventory. We here use a subset of the region 11 only (Oetztal Alps). As climate data we use the HISTALP dataset.

# %%
# read shapefile with 66 glaciers in the Oetztal Alps
rgidf = salem.read_shapefile('../rgi/oetztal.shp')

# sort for efficient using
rgidf = rgidf.sort_values('Area', ascending=False)
rgidf.plot()

# Use HISTALP climate file
cfg.PARAMS['baseline_climate'] = 'HISTALP'

# %% [markdown]
# ### Preprocessing of OGGM
# The function "preprocessing(gdirs)" runs all required steps of OGGM, before we can start to reconstruct the glacier. This includes e.g. the calculation of the flowlines, the processing of the HISTALP dataset, and the inversion.Cause to large computational costs, we will focus from now on one glacier (The Guslarferner), only.

# %%
# initization of OGGM
gdirs = workflow.init_glacier_regions(rgidf)
gdir = workflow.init_glacier_regions(rgidf[rgidf.RGIId == 'RGI60-11.00779'])[0]

# this function only needs to be run ONE time
preprocessing(gdirs)

gdir
# Out:
# <oggm.GlacierDirectory>
#   RGI id: RGI60-11.00779
#   Region: 11: Central Europe
#   Subregion: 11-01: Alps
#   Glacier type: Glacier
#   Terminus type: Land-terminating
#   Area: 1.375 km2
#   Lon, Lat: (10.8009, 46.8542)
#   Grid (nx, ny): (464, 456)
#   Grid (dx, dy): (26.0, -26.0)

# %% [markdown]
# ### Synthetic experiments
# We performed synthetic experiments to test the performance of our method. As the method is still under developpment, we recommend to use the method only in combination with the experiments. Otherwise it is not guaranteed, that the glacier candidates converge towards the observation and wrong reconstructions could result. A method to ensure this convergence will follow soon.

# %%
# add to BASENAMES
try:
    _doc = 'contains observed and searched glacier from synthetic experiment to find intial state'
    cfg.BASENAMES['synthetic_experiment'] = ('synthetic_experiment.pkl', _doc)
except:
    pass

# creates the experiments for a list of glacier in parallel
#synthetic_experiments_parallel([gdir])

# %% [markdown]
# A glacier for the year 1850 is created by running a random climate task with the temperature bias -1 for 400 years. This glacier will be run forward from 1850 to 2000. The resulting glacier is from now on the observed glacier.

# %%
# reads the expermient model
ep = gdir.get_filepath('model_run', filesuffix='_experiment')
ex_mod = FileModel(ep)

# plots cross section along the flowline in 1850 and 2000
plot_experiment(gdir,ex_mod,1850,cfg.PATHS['plot_dir'])

# %% [markdown]
# These plots show, that no ice left in 2000. Nevertheless, we try to reconstruct this glacier.

# %% [markdown]
# ### Reconstruction of the state in 1850
# To reconstruct the glacier you need to call the function `find_possible_glaciers(gdir,y0,ye,n)`, with the GlacierDirectory `gdir`, the year of the searched state `y0`, the year of the obersvation `ye` and `n` the number of glacier candidates to test. We choose `n=200` and reconstruct this glacier in `y0=1850`. This computation can take a while (...)

# %%
results = find_possible_glaciers(gdir, 1850, 2000, 200)
results['volume'] = results.model.apply(lambda x: x.volume_km3)
results
# Out:
#         fitness                                              model  temp_bias  \
# 0      0.522449  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 1      0.752940  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 2      0.734823  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 3      0.780345  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 4      0.882324  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 5      0.948432  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 6      1.017348  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 7      0.944786  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 8      0.787130  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 9      0.881156  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 10     0.925928  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 11     0.760066  <oggm.core.flowline.FileModel object at 0x7f4a...      -3.00
# 12     0.701145  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.50
# 13     0.710358  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.50
# 14     0.583296  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.50
# 15     0.540232  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.50
# 16     0.238474  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.40
# 17     0.443589  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.40
# 18     0.136049  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.35
# 19     0.002441  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.35
# 20     0.018265  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.35
# 21     0.135921  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.35
# 22     0.218462  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.30
# 23     0.119999  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.30
# 24     0.060386  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.30
# 25     0.755801  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.45
# 26     0.593772  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.45
# 27     0.444339  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.45
# 28     0.161349  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.25
# 29     0.141099  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.25
# ..          ...                                                ...        ...
# 170    0.528839  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.80
# 171    0.546437  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.80
# 172    0.386004  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.80
# 173  107.828048  <oggm.core.flowline.FileModel object at 0x7f4a...       0.90
# 174  136.884158  <oggm.core.flowline.FileModel object at 0x7f4a...       0.95
# 175    0.335224  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.75
# 176    0.676673  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.60
# 177    0.534425  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.60
# 178    0.561600  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.60
# 179    0.604358  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.60
# 180    0.199203  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.70
# 181    0.224595  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.70
# 182    0.372123  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.65
# 183    0.041180  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.65
# 184    0.193038  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.60
# 185    0.352018  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.60
# 186    0.601860  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.55
# 187    0.606596  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.55
# 188    0.517176  <oggm.core.flowline.FileModel object at 0x7f4a...      -2.55
# 189    0.104274  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.55
# 190    0.174830  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.55
# 191    0.129970  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.50
# 192    0.099964  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.50
# 193    0.175189  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.45
# 194    0.168639  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.45
# 195    0.341829  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.45
# 196    0.368724  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.45
# 197    0.377660  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.45
# 198    0.284552  <oggm.core.flowline.FileModel object at 0x7f4a...      -1.45
# 199  158.832386  <oggm.core.flowline.FileModel object at 0x7f4a...       1.95
#
#     time    volume
# 0    199  0.529406
# 1    212  0.563635
# 2    215  0.557474
# 3    237  0.554321
# 4    276  0.588546
# 5    319  0.610309
# 6    320  0.619742
# 7    323  0.613831
# 8    334  0.604426
# 9    369  0.601192
# 10   382  0.616310
# 11   399  0.566885
# 12   352  0.498284
# 13   358  0.501449
# 14   383  0.457795
# 15   392  0.454669
# 16   266  0.283403
# 17   332  0.305198
# 18   205  0.246044
# 19   220  0.230465
# 20   275  0.242925
# 21   320  0.249141
# 22   193  0.239811
# 23   215  0.261630
# 24   342  0.252252
# 25   224  0.495132
# 26   268  0.429796
# 27   289  0.414148
# 28   252  0.224190
# 29   326  0.214906
# ..   ...       ...
# 170  345  0.339427
# 171  381  0.379953
# 172  388  0.370595
# 173  262  0.006236
# 174  307  0.003115
# 175  240  0.308343
# 176  228  0.439165
# 177  232  0.432896
# 178  273  0.451565
# 179  291  0.460914
# 180  290  0.289628
# 181  396  0.320779
# 182  295  0.327001
# 183  306  0.286511
# 184  299  0.292737
# 185  367  0.311426
# 186  234  0.476501
# 187  282  0.473374
# 188  368  0.448460
# 189  252  0.267828
# 190  393  0.264728
# 191  196  0.274067
# 192  380  0.270963
# 193  252  0.258502
# 194  271  0.255437
# 195  297  0.277168
# 196  298  0.280331
# 197  316  0.295874
# 198  333  0.298936
# 199  400  0.000000
#
# [200 rows x 5 columns]

# %% [markdown]
# The output is a `panda.DataFrame()` with following informations for each tested glacier candidate: OGGM's FileModel of the past climate run from yr to ye, the objective (also called fitness) value, and the temperature bias and time point from the random climate runs to identify later which candidates was picked. From the FileModel all required inforamtions (e.g. volume, area, length, surface elevations at grid points) can be obtained. All previous model_runs will be saved and stored in a new directory named by the year. If the function should be run a second time for the same glacier (e.g. with more candidates), the algorithm first check, if this model_run was already done and reads the corresponding FileModel, if this is the case. Hereby it is avoided that the same runs will be run twice.

# %% [markdown]
# ### Graphics
# #### Glacier candidates
# The function `plot_candidates` plots the random climate tasks and the identified glacier candidates, colored by their Fitness value.

# %%
plot_candidates(gdir, results, 1850, cfg.PATHS['plot_dir'])

# %% [markdown]
# #### Cross-Section colored by Fitness value
# The function `plot_surface` plot the cross-Section along the main flowline of all glacier candidates at 1850 and 2000, as well as the volumes between 1850-2000.

# %%
plot_surface(gdir,results, ex_mod,1850,cfg.PATHS['plot_dir'])

# %% [markdown]
# We suggest to accept all candidates with a fitness value smaller than 125 (which are in this case all, except two). A good estimate could is the median state of the 5th percentile of all acceptable states.

# %%
results[results['fitness']<= 125]
# Out:
#         fitness                                              model  temp_bias  \
# 0      0.522449  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 1      0.752940  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 2      0.734823  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 3      0.780345  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 4      0.882324  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 5      0.948432  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 6      1.017348  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 7      0.944786  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 8      0.787130  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 9      0.881156  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 10     0.925928  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 11     0.760066  <oggm.core.flowline.FileModel object at 0x7f5f...      -3.00
# 12     0.701145  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.50
# 13     0.710358  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.50
# 14     0.583296  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.50
# 15     0.540232  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.50
# 16     0.238474  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.40
# 17     0.443589  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.40
# 18     0.136049  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.35
# 19     0.002441  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.35
# 20     0.018265  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.35
# 21     0.135921  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.35
# 22     0.218462  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.30
# 23     0.119999  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.30
# 24     0.060386  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.30
# 25     0.755801  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.45
# 26     0.593772  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.45
# 27     0.444339  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.45
# 28     0.161349  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.25
# 29     0.141099  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.25
# ..          ...                                                ...        ...
# 168   81.394232  <oggm.core.flowline.FileModel object at 0x7f5f...       0.75
# 169    0.415281  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.80
# 170    0.528839  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.80
# 171    0.546437  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.80
# 172    0.386004  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.80
# 173  107.828048  <oggm.core.flowline.FileModel object at 0x7f5f...       0.90
# 175    0.335224  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.75
# 176    0.676673  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.60
# 177    0.534425  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.60
# 178    0.561600  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.60
# 179    0.604358  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.60
# 180    0.199203  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.70
# 181    0.224595  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.70
# 182    0.372123  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.65
# 183    0.041180  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.65
# 184    0.193038  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.60
# 185    0.352018  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.60
# 186    0.601860  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.55
# 187    0.606596  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.55
# 188    0.517176  <oggm.core.flowline.FileModel object at 0x7f5f...      -2.55
# 189    0.104274  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.55
# 190    0.174830  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.55
# 191    0.129970  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.50
# 192    0.099964  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.50
# 193    0.175189  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.45
# 194    0.168639  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.45
# 195    0.341829  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.45
# 196    0.368724  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.45
# 197    0.377660  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.45
# 198    0.284552  <oggm.core.flowline.FileModel object at 0x7f5f...      -1.45
#
#      time    volume  Fitness value
# 0     199  0.529406       0.522449
# 1     212  0.563635       0.752940
# 2     215  0.557474       0.734823
# 3     237  0.554321       0.780345
# 4     276  0.588546       0.882324
# 5     319  0.610309       0.948432
# 6     320  0.619742       1.017348
# 7     323  0.613831       0.944786
# 8     334  0.604426       0.787130
# 9     369  0.601192       0.881156
# 10    382  0.616310       0.925928
# 11    399  0.566885       0.760066
# 12    352  0.498284       0.701145
# 13    358  0.501449       0.710358
# 14    383  0.457795       0.583296
# 15    392  0.454669       0.540232
# 16    266  0.283403       0.238474
# 17    332  0.305198       0.443589
# 18    205  0.246044       0.136049
# 19    220  0.230465       0.002441
# 20    275  0.242925       0.018265
# 21    320  0.249141       0.135921
# 22    193  0.239811       0.218462
# 23    215  0.261630       0.119999
# 24    342  0.252252       0.060386
# 25    224  0.495132       0.755801
# 26    268  0.429796       0.593772
# 27    289  0.414148       0.444339
# 28    252  0.224190       0.161349
# 29    326  0.214906       0.141099
# ..    ...       ...            ...
# 168   295  0.009345      81.394232
# 169   336  0.323884       0.415281
# 170   345  0.339427       0.528839
# 171   381  0.379953       0.546437
# 172   388  0.370595       0.386004
# 173   262  0.006236     107.828048
# 175   240  0.308343       0.335224
# 176   228  0.439165       0.676673
# 177   232  0.432896       0.534425
# 178   273  0.451565       0.561600
# 179   291  0.460914       0.604358
# 180   290  0.289628       0.199203
# 181   396  0.320779       0.224595
# 182   295  0.327001       0.372123
# 183   306  0.286511       0.041180
# 184   299  0.292737       0.193038
# 185   367  0.311426       0.352018
# 186   234  0.476501       0.601860
# 187   282  0.473374       0.606596
# 188   368  0.448460       0.517176
# 189   252  0.267828       0.104274
# 190   393  0.264728       0.174830
# 191   196  0.274067       0.129970
# 192   380  0.270963       0.099964
# 193   252  0.258502       0.175189
# 194   271  0.255437       0.168639
# 195   297  0.277168       0.341829
# 196   298  0.280331       0.368724
# 197   316  0.295874       0.377660
# 198   333  0.298936       0.284552
#
# [198 rows x 6 columns]

# %% [markdown]
# #### Median state
# We also found out that the median state of the 5% quantile of all glaciers with a fitness value smaller than 125 fits well with the experient. To create a plot, showing the interquantile range and the median state you can use the function `plot_median`:

# %%
med_mod = plot_median(gdir,results,ex_mod,1850, cfg.PATHS['plot_dir'])

# %% [markdown]
# The grey area, shows all glacier states with a fitness value smaller than 125. The blue area is the 5% quantile and the blue line represents the median state. Additionally this function returns the FileModel of the median state to be able to use it for other runs. This is the best estimate of the reconstructed state in 1850.

# %% [markdown]
# The uncertainties of the method are reduces, when running this state forward in time. To do so use:

# %%
print('error to experiment in 1850:', str(med_mod.volume_km3_ts()[1850]-ex_mod.volume_km3_ts()[1850]))

print('error to experiment in 1900', str(med_mod.volume_km3_ts()[1900]-ex_mod.volume_km3_ts()[1900]))

print('error to experiment in 1950', str(med_mod.volume_km3_ts()[1950]-ex_mod.volume_km3_ts()[1950]))
# Out:
# error to experiment in 1850: 0.007603731684146325
# error to experiment in 1900 0.0016645326900509017
# error to experiment in 1950 0.0005380207716161878
